# %%
import tensorflow as tf
print(tf.__version__)
from tensorflow.keras.optimizers import Adam
# Out:
# 2.9.2

# %%
# Library untuk mengimport tensorflow
import tensorflow as tf
print('Versi Tensor Flow yang digunakan adalah versi : ',tf.__version__)
from tensorflow.keras.optimizers import Adam

# mount drive dan import file
import zipfile, os

from google.colab import drive
drive.mount('/content/drive')
# melakukan ekstraksi pada file zip
local_zip = '/content/drive/MyDrive/Data Batiknyo.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

# Membaca Direktori Awal
base_dir = '/content/Data Batiknyo'
print ("\n Disini terdapat Folder : ")
# !ls "/content/Data Batiknyo"
# Out:
# Versi Tensor Flow yang digunakan adalah versi :  2.9.2

# %%
train_dir = os.path.join(base_dir, 'train')
print ('Jumlah Folder pada direktory train : ' , len(os.listdir(train_dir)))

# membaca direktori pada folder train (class train)
os.listdir(train_dir)
# Out:
# Jumlah Folder pada direktory train :  3
# ['Batik Megamendung', 'Batik Parang', 'Batik Poleng']

# %%
validation_dir = os.path.join(base_dir, 'val')

print ('Jumlah Folder pada direktory val : ' , len (os.listdir(validation_dir)))

# membaca direktori pada folder val (class val)
os.listdir(validation_dir)
# Out:
# Jumlah Folder pada direktory val :  3
# ['Batik Megamendung', 'Batik Parang', 'Batik Poleng']

# %%
# membuat direktori Batik pada direktori data TRAINING

train_megamendung_dir = os.path.join(train_dir, 'Batik Megamendung')
train_poleng_dir = os.path.join(train_dir, 'Batik Poleng')
train_parang_dir = os.path.join(train_dir, 'Batik Parang')

print('Jumlah gambar batik megamendung : ' , len(os.listdir(train_megamendung_dir)))
print('Jumlah gambar batik poleng : ' , len(os.listdir(train_poleng_dir)))
print('Jumlah gambar batik parang : ' , len(os.listdir(train_parang_dir)))
print ('total = ' , len(os.listdir(train_megamendung_dir))+len(os.listdir(train_poleng_dir))+len(os.listdir(train_parang_dir)))




# membuat direktori Batik pada direktori data Testing

validation_megamendung_dir = os.path.join(validation_dir, 'Batik Megamendung')

validation_poleng_dir = os.path.join(validation_dir, 'Batik Poleng')
validation_parang_dir = os.path.join(validation_dir, 'Batik Parang')

print('Jumlah gambar batik megamendung : ' , len(os.listdir(validation_megamendung_dir)))
print('Jumlah gambar batik poleng : ' , len(os.listdir(validation_poleng_dir)))
print('Jumlah gambar batik parang : ' , len(os.listdir(validation_parang_dir)))
print ('total = ' , len(os.listdir(validation_megamendung_dir))+len(os.listdir(validation_poleng_dir))+len(os.listdir(validation_parang_dir)))
# Out:
# Jumlah gambar batik megamendung :  72
# Jumlah gambar batik poleng :  72
# Jumlah gambar batik parang :  72
# total =  216
# Jumlah gambar batik megamendung :  8
# Jumlah gambar batik poleng :  8
# Jumlah gambar batik parang :  8
# total =  24

# %%
# import random
# from shutil import copyfile

# def train_val_split(source , train, val , train_ratio):
#   total_size = len(os.listdir(source))
#   train_size = int(train_ratio * total_size)
#   val_size = total_size - train_size

#   randomized = random.sample(os.listdir(source) , total_size)
#   train_files = randomized[0:train_size]
#   val_files = randomized[train_size:total_size]

#   for i in train_files :
#     i_file = source + i
#     destination = train + 1
#     copyfile(i_file , destination)

#     for i in val_files :
#       i_file = source + i
#       destination = train + 1
#       copyfile(i_file , destination)

#     #jumlah pembagian data training dan testing
#     train_ratio = 0.9

#     #pembagian training dan validasi
#     source_00 = train_megamendung_dir
#     train_00 = train_megamendung
#     val_00 = validation_megamendung_dir
#     train_val_split(source_00 , train_00, val_00 , train_ratio)

#     source_00 = train_megamendung_dir
#     train_00 = train_megamendung
#     val_00 = validation_megamendung_dir
#     train_val_split(source_01 , train_01, val_01 , train_ratio)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=30,
                    horizontal_flip = True,
                    shear_range = 0.3,
                    fill_mode = 'nearest',
                    width_shift_range = 0.2 ,
                    height_shift_range = 0.2,
                    zoom_range = 0.1)

test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=30,
                    horizontal_flip = True,
                    shear_range = 0.3,
                    fill_mode = 'nearest',
                     width_shift_range = 0.2 ,
                    height_shift_range = 0.2,
                    zoom_range = 0.1)

# %%
batch = 24
train_generator = train_datagen.flow_from_directory(
        train_dir,  # direktori data latih
        target_size=(224, 224),  # mengubah resolusi seluruh gambar
        batch_size=batch,
        color_mode="rgb",
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir, # direktori data validasi
        target_size=(224, 224), # mengubah resolusi seluruh gambar
        batch_size=batch,
        color_mode="rgb",
        class_mode='categorical',
        shuffle=True)
# Out:
# Found 216 images belonging to 3 classes.
# Found 24 images belonging to 3 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Conv2D(96, (3,3), activation='relu'),
    # tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(200, activation='relu'),
    tf.keras.layers.Dropout(0.3, seed = 112),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5, seed = 112),
    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
# lr = 0.00005
# tf.keras.optimizers.Adam(learning_rate=lr)
# compile model dengan 'adam' optimizer loss function 'categorical_crossentropy'
model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# %%
epoch = 200
# latih model dengan model.fit 
history = model.fit(
      train_generator,
      steps_per_epoch=train_generator.samples//train_generator.batch_size,  # berapa batch yang akan dieksekusi pada setiap epoch
      epochs=epoch, # tambahkan eposchs jika akurasi model belum optimal
      validation_data=validation_generator, # menampilkan akurasi pengujian data validasi
      validation_steps=validation_generator.samples//validation_generator.batch_size,  # berapa batch yang akan dieksekusi pada setiap epoch
      verbose=1)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 4s 379ms/step - loss: 1.9266 - accuracy: 0.3565 - val_loss: 1.0935 - val_accuracy: 0.3333
# Epoch 2/200
# 9/9 [==============================] - 3s 327ms/step - loss: 1.0829 - accuracy: 0.3241 - val_loss: 1.0963 - val_accuracy: 0.2917
# Epoch 3/200
# 9/9 [==============================] - 3s 327ms/step - loss: 1.0026 - accuracy: 0.4028 - val_loss: 1.2248 - val_accuracy: 0.5000
# Epoch 4/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.9267 - accuracy: 0.5880 - val_loss: 1.3378 - val_accuracy: 0.5833
# Epoch 5/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.9388 - accuracy: 0.5556 - val_loss: 1.1960 - val_accuracy: 0.4167
# Epoch 6/200
# 9/9 [==============================] - 3s 330ms/step - loss: 0.9466 - accuracy: 0.5509 - val_loss: 1.4545 - val_accuracy: 0.4583
# Epoch 7/200
# 9/9 [==============================] - 3s 336ms/step - loss: 0.9965 - accuracy: 0.5370 - val_loss: 1.1086 - val_accuracy: 0.4167
# Epoch 8/200
# 9/9 [==============================] - 3s 335ms/step - loss: 0.9564 - accuracy: 0.5139 - val_loss: 1.2656 - val_accuracy: 0.5000
# Epoch 9/200
# 9/9 [==============================] - 3s 338ms/step - loss: 0.8440 - accuracy: 0.6296 - val_loss: 1.1719 - val_accuracy: 0.5833
# Epoch 10/200
# 9/9 [==============================] - 3s 330ms/step - loss: 0.8006 - accuracy: 0.6343 - val_loss: 1.2558 - val_accuracy: 0.5833
# Epoch 11/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.8273 - accuracy: 0.6667 - val_loss: 1.1553 - val_accuracy: 0.6667
# Epoch 12/200
# 9/9 [==============================] - 3s 328ms/step - loss: 0.7604 - accuracy: 0.6806 - val_loss: 1.0456 - val_accuracy: 0.7083
# Epoch 13/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.7210 - accuracy: 0.7407 - val_loss: 1.2407 - val_accuracy: 0.5417
# Epoch 14/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.7616 - accuracy: 0.6528 - val_loss: 0.9918 - val_accuracy: 0.6667
# Epoch 15/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.7376 - accuracy: 0.7037 - val_loss: 1.1365 - val_accuracy: 0.6250
# Epoch 16/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.7123 - accuracy: 0.6852 - val_loss: 1.0044 - val_accuracy: 0.5833
# Epoch 17/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.6698 - accuracy: 0.7361 - val_loss: 1.0753 - val_accuracy: 0.6250
# Epoch 18/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.6660 - accuracy: 0.7407 - val_loss: 1.1823 - val_accuracy: 0.5833
# Epoch 19/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.6203 - accuracy: 0.7454 - val_loss: 0.8134 - val_accuracy: 0.7083
# Epoch 20/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.6417 - accuracy: 0.7454 - val_loss: 0.9397 - val_accuracy: 0.7083
# Epoch 21/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.5652 - accuracy: 0.7963 - val_loss: 0.8215 - val_accuracy: 0.6667
# Epoch 22/200
# 9/9 [==============================] - 3s 328ms/step - loss: 0.5612 - accuracy: 0.7963 - val_loss: 0.9221 - val_accuracy: 0.6667
# Epoch 23/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.5814 - accuracy: 0.7870 - val_loss: 0.7607 - val_accuracy: 0.7500
# Epoch 24/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.5335 - accuracy: 0.8009 - val_loss: 0.7179 - val_accuracy: 0.6667
# Epoch 25/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.4996 - accuracy: 0.8194 - val_loss: 0.6470 - val_accuracy: 0.7500
# Epoch 26/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.4823 - accuracy: 0.8148 - val_loss: 0.8285 - val_accuracy: 0.7083
# Epoch 27/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.5083 - accuracy: 0.7963 - val_loss: 0.9637 - val_accuracy: 0.6250
# Epoch 28/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.4748 - accuracy: 0.8148 - val_loss: 0.8192 - val_accuracy: 0.6667
# Epoch 29/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.4561 - accuracy: 0.8194 - val_loss: 0.8050 - val_accuracy: 0.7083
# Epoch 30/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.4558 - accuracy: 0.8380 - val_loss: 0.5854 - val_accuracy: 0.7500
# Epoch 31/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.4234 - accuracy: 0.8194 - val_loss: 0.6116 - val_accuracy: 0.7917
# Epoch 32/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.4058 - accuracy: 0.8519 - val_loss: 0.6924 - val_accuracy: 0.7917
# Epoch 33/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.5300 - accuracy: 0.8056 - val_loss: 0.5569 - val_accuracy: 0.7500
# Epoch 34/200
# 9/9 [==============================] - 3s 328ms/step - loss: 0.4378 - accuracy: 0.8241 - val_loss: 0.7902 - val_accuracy: 0.6667
# Epoch 35/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.4253 - accuracy: 0.8472 - val_loss: 0.7322 - val_accuracy: 0.7500
# Epoch 36/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.4657 - accuracy: 0.7963 - val_loss: 0.6534 - val_accuracy: 0.7500
# Epoch 37/200
# 9/9 [==============================] - 3s 328ms/step - loss: 0.4489 - accuracy: 0.8287 - val_loss: 0.6598 - val_accuracy: 0.7083
# Epoch 38/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.3780 - accuracy: 0.8657 - val_loss: 0.5070 - val_accuracy: 0.8333
# Epoch 39/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.3920 - accuracy: 0.8519 - val_loss: 0.5736 - val_accuracy: 0.7917
# Epoch 40/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.3967 - accuracy: 0.8657 - val_loss: 0.4647 - val_accuracy: 0.7917
# Epoch 41/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.3584 - accuracy: 0.8796 - val_loss: 0.3824 - val_accuracy: 0.8750
# Epoch 42/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.3122 - accuracy: 0.8796 - val_loss: 0.5235 - val_accuracy: 0.7917
# Epoch 43/200
# 9/9 [==============================] - 3s 330ms/step - loss: 0.3110 - accuracy: 0.8750 - val_loss: 0.5627 - val_accuracy: 0.7917
# Epoch 44/200
# 9/9 [==============================] - 3s 328ms/step - loss: 0.3639 - accuracy: 0.8657 - val_loss: 0.5625 - val_accuracy: 0.7083
# Epoch 45/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.3927 - accuracy: 0.8611 - val_loss: 0.7389 - val_accuracy: 0.7500
# Epoch 46/200
# 9/9 [==============================] - 3s 336ms/step - loss: 0.4197 - accuracy: 0.8519 - val_loss: 0.6854 - val_accuracy: 0.7083
# Epoch 47/200
# 9/9 [==============================] - 3s 329ms/step - loss: 0.3698 - accuracy: 0.8704 - val_loss: 0.4705 - val_accuracy: 0.7917
# Epoch 48/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.3892 - accuracy: 0.8657 - val_loss: 0.6007 - val_accuracy: 0.7917
# Epoch 49/200
# 9/9 [==============================] - 3s 330ms/step - loss: 0.3224 - accuracy: 0.8796 - val_loss: 0.3647 - val_accuracy: 0.8750
# Epoch 50/200
# 9/9 [==============================] - 3s 333ms/step - loss: 0.2477 - accuracy: 0.9213 - val_loss: 0.4133 - val_accuracy: 0.8750
# Epoch 51/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.3577 - accuracy: 0.8657 - val_loss: 0.6983 - val_accuracy: 0.6667
# Epoch 52/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.3390 - accuracy: 0.8750 - val_loss: 0.4820 - val_accuracy: 0.7917
# Epoch 53/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.3932 - accuracy: 0.8704 - val_loss: 0.4746 - val_accuracy: 0.8750
# Epoch 54/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.4650 - accuracy: 0.8472 - val_loss: 0.6475 - val_accuracy: 0.7500
# Epoch 55/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.3958 - accuracy: 0.8611 - val_loss: 0.4542 - val_accuracy: 0.7917
# Epoch 56/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.3332 - accuracy: 0.8843 - val_loss: 0.5570 - val_accuracy: 0.7917
# Epoch 57/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.3639 - accuracy: 0.8750 - val_loss: 0.4025 - val_accuracy: 0.8333
# Epoch 58/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.3408 - accuracy: 0.8750 - val_loss: 0.5074 - val_accuracy: 0.8750
# Epoch 59/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.2975 - accuracy: 0.8889 - val_loss: 0.5236 - val_accuracy: 0.7917
# Epoch 60/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.2549 - accuracy: 0.9120 - val_loss: 0.5055 - val_accuracy: 0.8333
# Epoch 61/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.2373 - accuracy: 0.9213 - val_loss: 0.2795 - val_accuracy: 0.9167
# Epoch 62/200
# 9/9 [==============================] - 3s 343ms/step - loss: 0.2042 - accuracy: 0.9352 - val_loss: 0.3148 - val_accuracy: 0.8750
# Epoch 63/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.2232 - accuracy: 0.9213 - val_loss: 0.3929 - val_accuracy: 0.8750
# Epoch 64/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.2764 - accuracy: 0.9213 - val_loss: 0.2206 - val_accuracy: 0.9167
# Epoch 65/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.2333 - accuracy: 0.9074 - val_loss: 0.2134 - val_accuracy: 0.9167
# Epoch 66/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.2103 - accuracy: 0.9583 - val_loss: 0.2615 - val_accuracy: 0.8750
# Epoch 67/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.2113 - accuracy: 0.9167 - val_loss: 0.3768 - val_accuracy: 0.8750
# Epoch 68/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.2728 - accuracy: 0.8935 - val_loss: 0.7695 - val_accuracy: 0.7500
# Epoch 69/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.2846 - accuracy: 0.9028 - val_loss: 0.3291 - val_accuracy: 0.9167
# Epoch 70/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.2998 - accuracy: 0.8796 - val_loss: 0.3683 - val_accuracy: 0.8750
# Epoch 71/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.3344 - accuracy: 0.8889 - val_loss: 0.4812 - val_accuracy: 0.9167
# Epoch 72/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.2708 - accuracy: 0.9120 - val_loss: 0.2845 - val_accuracy: 0.8750
# Epoch 73/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.2265 - accuracy: 0.9259 - val_loss: 0.2378 - val_accuracy: 0.9167
# Epoch 74/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1623 - accuracy: 0.9398 - val_loss: 0.2715 - val_accuracy: 0.9167
# Epoch 75/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.1777 - accuracy: 0.9306 - val_loss: 0.2374 - val_accuracy: 0.8750
# Epoch 76/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.2030 - accuracy: 0.9306 - val_loss: 0.2852 - val_accuracy: 0.9167
# Epoch 77/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.2497 - accuracy: 0.8843 - val_loss: 0.2961 - val_accuracy: 0.8750
# Epoch 78/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.2540 - accuracy: 0.9028 - val_loss: 0.1901 - val_accuracy: 0.9583
# Epoch 79/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.1592 - accuracy: 0.9352 - val_loss: 0.3158 - val_accuracy: 0.8750
# Epoch 80/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1621 - accuracy: 0.9398 - val_loss: 0.3729 - val_accuracy: 0.8333
# Epoch 81/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.1474 - accuracy: 0.9444 - val_loss: 0.3492 - val_accuracy: 0.8333
# Epoch 82/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.2136 - accuracy: 0.9213 - val_loss: 0.4582 - val_accuracy: 0.8333
# Epoch 83/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.2735 - accuracy: 0.9213 - val_loss: 0.4759 - val_accuracy: 0.7917
# Epoch 84/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.2727 - accuracy: 0.9167 - val_loss: 0.6302 - val_accuracy: 0.7500
# Epoch 85/200
# 9/9 [==============================] - 3s 333ms/step - loss: 0.2146 - accuracy: 0.9398 - val_loss: 0.4278 - val_accuracy: 0.8750
# Epoch 86/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.2226 - accuracy: 0.9306 - val_loss: 0.4252 - val_accuracy: 0.8333
# Epoch 87/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.3188 - accuracy: 0.8889 - val_loss: 0.4523 - val_accuracy: 0.8333
# Epoch 88/200
# 9/9 [==============================] - 3s 329ms/step - loss: 0.2326 - accuracy: 0.9120 - val_loss: 0.2647 - val_accuracy: 0.8750
# Epoch 89/200
# 9/9 [==============================] - 3s 333ms/step - loss: 0.2645 - accuracy: 0.8796 - val_loss: 0.7024 - val_accuracy: 0.8333
# Epoch 90/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.2382 - accuracy: 0.9537 - val_loss: 0.4882 - val_accuracy: 0.7917
# Epoch 91/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.3625 - accuracy: 0.8935 - val_loss: 0.4417 - val_accuracy: 0.7917
# Epoch 92/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.2313 - accuracy: 0.9259 - val_loss: 0.4967 - val_accuracy: 0.8333
# Epoch 93/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.2185 - accuracy: 0.9259 - val_loss: 0.3815 - val_accuracy: 0.8333
# Epoch 94/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1736 - accuracy: 0.9352 - val_loss: 0.2173 - val_accuracy: 0.9167
# Epoch 95/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.1802 - accuracy: 0.9398 - val_loss: 0.2837 - val_accuracy: 0.8750
# Epoch 96/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.1685 - accuracy: 0.9352 - val_loss: 0.2089 - val_accuracy: 0.8750
# Epoch 97/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1451 - accuracy: 0.9398 - val_loss: 0.2701 - val_accuracy: 0.8750
# Epoch 98/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.2044 - accuracy: 0.9398 - val_loss: 0.2756 - val_accuracy: 0.8750
# Epoch 99/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1597 - accuracy: 0.9537 - val_loss: 0.2985 - val_accuracy: 0.9167
# Epoch 100/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.2145 - accuracy: 0.9444 - val_loss: 0.1861 - val_accuracy: 0.9167
# Epoch 101/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1234 - accuracy: 0.9491 - val_loss: 0.1876 - val_accuracy: 0.9167
# Epoch 102/200
# 9/9 [==============================] - 3s 315ms/step - loss: 0.1637 - accuracy: 0.9398 - val_loss: 0.1625 - val_accuracy: 0.9583
# Epoch 103/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1855 - accuracy: 0.9398 - val_loss: 0.2469 - val_accuracy: 0.9167
# Epoch 104/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.1685 - accuracy: 0.9491 - val_loss: 0.3785 - val_accuracy: 0.8750
# Epoch 105/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1237 - accuracy: 0.9676 - val_loss: 0.1427 - val_accuracy: 0.9167
# Epoch 106/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1714 - accuracy: 0.9306 - val_loss: 0.2317 - val_accuracy: 0.9583
# Epoch 107/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1327 - accuracy: 0.9491 - val_loss: 0.1875 - val_accuracy: 0.9583
# Epoch 108/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.0991 - accuracy: 0.9676 - val_loss: 0.1983 - val_accuracy: 0.9167
# Epoch 109/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.1168 - accuracy: 0.9769 - val_loss: 0.1146 - val_accuracy: 0.9583
# Epoch 110/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0655 - accuracy: 0.9815 - val_loss: 0.1601 - val_accuracy: 0.9583
# Epoch 111/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.0573 - accuracy: 0.9861 - val_loss: 0.1795 - val_accuracy: 0.9167
# Epoch 112/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0629 - accuracy: 0.9815 - val_loss: 0.2534 - val_accuracy: 0.9167
# Epoch 113/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.1242 - accuracy: 0.9491 - val_loss: 0.0598 - val_accuracy: 0.9583
# Epoch 114/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.1124 - accuracy: 0.9398 - val_loss: 0.1113 - val_accuracy: 0.9167
# Epoch 115/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.2004 - accuracy: 0.9398 - val_loss: 0.1050 - val_accuracy: 0.9583
# Epoch 116/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.1480 - accuracy: 0.9491 - val_loss: 0.1453 - val_accuracy: 0.9583
# Epoch 117/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.1335 - accuracy: 0.9537 - val_loss: 0.1735 - val_accuracy: 0.9167
# Epoch 118/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1447 - accuracy: 0.9583 - val_loss: 0.3984 - val_accuracy: 0.8333
# Epoch 119/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.1644 - accuracy: 0.9352 - val_loss: 0.1398 - val_accuracy: 0.9583
# Epoch 120/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1656 - accuracy: 0.9491 - val_loss: 0.2510 - val_accuracy: 0.8750
# Epoch 121/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.1308 - accuracy: 0.9630 - val_loss: 0.1603 - val_accuracy: 0.9167
# Epoch 122/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1201 - accuracy: 0.9583 - val_loss: 0.1944 - val_accuracy: 0.9167
# Epoch 123/200
# 9/9 [==============================] - 3s 316ms/step - loss: 0.1211 - accuracy: 0.9537 - val_loss: 0.2300 - val_accuracy: 0.9167
# Epoch 124/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.1107 - accuracy: 0.9630 - val_loss: 0.1363 - val_accuracy: 0.9167
# Epoch 125/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.2564 - accuracy: 0.9306 - val_loss: 0.2864 - val_accuracy: 0.8750
# Epoch 126/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.1661 - accuracy: 0.9398 - val_loss: 0.3078 - val_accuracy: 0.8750
# Epoch 127/200
# 9/9 [==============================] - 3s 316ms/step - loss: 0.1260 - accuracy: 0.9491 - val_loss: 0.2322 - val_accuracy: 0.9167
# Epoch 128/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.1345 - accuracy: 0.9444 - val_loss: 0.1450 - val_accuracy: 0.9583
# Epoch 129/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0870 - accuracy: 0.9769 - val_loss: 0.1290 - val_accuracy: 0.9167
# Epoch 130/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.2279 - accuracy: 0.9491 - val_loss: 0.3976 - val_accuracy: 0.9167
# Epoch 131/200
# 9/9 [==============================] - 3s 315ms/step - loss: 0.2143 - accuracy: 0.9306 - val_loss: 0.1144 - val_accuracy: 0.9583
# Epoch 132/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1881 - accuracy: 0.9259 - val_loss: 0.2986 - val_accuracy: 0.8750
# Epoch 133/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.1826 - accuracy: 0.9259 - val_loss: 0.1903 - val_accuracy: 0.9167
# Epoch 134/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.1027 - accuracy: 0.9676 - val_loss: 0.1180 - val_accuracy: 0.9167
# Epoch 135/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1083 - accuracy: 0.9537 - val_loss: 0.0661 - val_accuracy: 0.9583
# Epoch 136/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0864 - accuracy: 0.9676 - val_loss: 0.1325 - val_accuracy: 0.9583
# Epoch 137/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1253 - accuracy: 0.9444 - val_loss: 0.1344 - val_accuracy: 0.9583
# Epoch 138/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.1007 - accuracy: 0.9583 - val_loss: 0.1288 - val_accuracy: 0.9583
# Epoch 139/200
# 9/9 [==============================] - 5s 536ms/step - loss: 0.0753 - accuracy: 0.9722 - val_loss: 0.1254 - val_accuracy: 0.9583
# Epoch 140/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.0442 - accuracy: 0.9907 - val_loss: 0.0944 - val_accuracy: 0.9583
# Epoch 141/200
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0712 - accuracy: 0.9722 - val_loss: 0.0546 - val_accuracy: 1.0000
# Epoch 142/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0802 - accuracy: 0.9630 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 143/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.0836 - accuracy: 0.9769 - val_loss: 0.1055 - val_accuracy: 0.9583
# Epoch 144/200
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0870 - accuracy: 0.9722 - val_loss: 0.3520 - val_accuracy: 0.8750
# Epoch 145/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1007 - accuracy: 0.9444 - val_loss: 0.0873 - val_accuracy: 0.9583
# Epoch 146/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0998 - accuracy: 0.9630 - val_loss: 0.1068 - val_accuracy: 0.9167
# Epoch 147/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1235 - accuracy: 0.9583 - val_loss: 0.0947 - val_accuracy: 0.9583
# Epoch 148/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1097 - accuracy: 0.9583 - val_loss: 0.2058 - val_accuracy: 0.9583
# Epoch 149/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0889 - accuracy: 0.9769 - val_loss: 0.2033 - val_accuracy: 0.9167
# Epoch 150/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1000 - accuracy: 0.9583 - val_loss: 0.1476 - val_accuracy: 0.9583
# Epoch 151/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.1234 - accuracy: 0.9537 - val_loss: 0.0961 - val_accuracy: 0.9167
# Epoch 152/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0940 - accuracy: 0.9630 - val_loss: 0.1963 - val_accuracy: 0.9167
# Epoch 153/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.1362 - accuracy: 0.9583 - val_loss: 0.1346 - val_accuracy: 0.9583
# Epoch 154/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0968 - accuracy: 0.9769 - val_loss: 0.1392 - val_accuracy: 0.9583
# Epoch 155/200
# 9/9 [==============================] - 3s 317ms/step - loss: 0.0621 - accuracy: 0.9815 - val_loss: 0.0716 - val_accuracy: 1.0000
# Epoch 156/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0627 - accuracy: 0.9861 - val_loss: 0.0921 - val_accuracy: 0.9583
# Epoch 157/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0608 - accuracy: 0.9815 - val_loss: 0.1382 - val_accuracy: 0.9583
# Epoch 158/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.0409 - accuracy: 0.9861 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 159/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0711 - accuracy: 0.9722 - val_loss: 0.0465 - val_accuracy: 0.9583
# Epoch 160/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0501 - accuracy: 0.9861 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 161/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0797 - accuracy: 0.9537 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 162/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.1007 - accuracy: 0.9537 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 163/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1269 - accuracy: 0.9537 - val_loss: 0.1163 - val_accuracy: 0.9583
# Epoch 164/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.1744 - accuracy: 0.9398 - val_loss: 0.3608 - val_accuracy: 0.8750
# Epoch 165/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.1780 - accuracy: 0.9259 - val_loss: 0.1794 - val_accuracy: 0.9583
# Epoch 166/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1353 - accuracy: 0.9769 - val_loss: 0.1891 - val_accuracy: 0.9583
# Epoch 167/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.1322 - accuracy: 0.9537 - val_loss: 0.0629 - val_accuracy: 1.0000
# Epoch 168/200
# 9/9 [==============================] - 3s 331ms/step - loss: 0.1071 - accuracy: 0.9722 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 169/200
# 9/9 [==============================] - 3s 332ms/step - loss: 0.0709 - accuracy: 0.9722 - val_loss: 0.1095 - val_accuracy: 0.9583
# Epoch 170/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0608 - accuracy: 0.9815 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 171/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0430 - accuracy: 0.9861 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 172/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0434 - accuracy: 0.9815 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 173/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.0465 - accuracy: 0.9815 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 174/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0592 - accuracy: 0.9815 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 175/200
# 9/9 [==============================] - 3s 325ms/step - loss: 0.0724 - accuracy: 0.9815 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 176/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0657 - accuracy: 0.9722 - val_loss: 0.2067 - val_accuracy: 0.8750
# Epoch 177/200
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0867 - accuracy: 0.9630 - val_loss: 0.1276 - val_accuracy: 0.9583
# Epoch 178/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.1673 - accuracy: 0.9537 - val_loss: 0.1858 - val_accuracy: 0.9583
# Epoch 179/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.1301 - accuracy: 0.9583 - val_loss: 0.0830 - val_accuracy: 0.9583
# Epoch 180/200
# 9/9 [==============================] - 3s 324ms/step - loss: 0.1597 - accuracy: 0.9676 - val_loss: 0.0600 - val_accuracy: 0.9583
# Epoch 181/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.1295 - accuracy: 0.9676 - val_loss: 0.1415 - val_accuracy: 0.9167
# Epoch 182/200
# 9/9 [==============================] - 3s 327ms/step - loss: 0.0717 - accuracy: 0.9815 - val_loss: 0.0798 - val_accuracy: 0.9583
# Epoch 183/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0739 - accuracy: 0.9722 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 184/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0470 - accuracy: 0.9861 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 185/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0657 - accuracy: 0.9769 - val_loss: 0.0423 - val_accuracy: 0.9583
# Epoch 186/200
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0581 - accuracy: 0.9676 - val_loss: 0.0641 - val_accuracy: 0.9583
# Epoch 187/200
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0602 - accuracy: 0.9769 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 188/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.0935 - accuracy: 0.9722 - val_loss: 0.0573 - val_accuracy: 0.9583
# Epoch 189/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0597 - accuracy: 0.9815 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 190/200
# 9/9 [==============================] - 3s 322ms/step - loss: 0.0945 - accuracy: 0.9722 - val_loss: 0.0895 - val_accuracy: 0.9583
# Epoch 191/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0606 - accuracy: 0.9769 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 192/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.0686 - accuracy: 0.9769 - val_loss: 0.0800 - val_accuracy: 0.9583
# Epoch 193/200
# 9/9 [==============================] - 3s 319ms/step - loss: 0.1250 - accuracy: 0.9769 - val_loss: 0.1982 - val_accuracy: 0.9167
# Epoch 194/200
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0520 - accuracy: 0.9815 - val_loss: 0.0630 - val_accuracy: 1.0000
# Epoch 195/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0470 - accuracy: 0.9861 - val_loss: 0.0389 - val_accuracy: 0.9583
# Epoch 196/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0823 - accuracy: 0.9583 - val_loss: 0.0752 - val_accuracy: 0.9583
# Epoch 197/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0275 - accuracy: 0.9954 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 198/200
# 9/9 [==============================] - 3s 320ms/step - loss: 0.1063 - accuracy: 0.9583 - val_loss: 0.3341 - val_accuracy: 0.9167
# Epoch 199/200
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0719 - accuracy: 0.9815 - val_loss: 0.0602 - val_accuracy: 0.9583
# Epoch 200/200
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0611 - accuracy: 0.9676 - val_loss: 0.0855 - val_accuracy: 0.9583

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='best')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),max(plt.ylim())])
plt.title('Training and Validation Accuracy')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='best')
plt.ylabel('Loss')
plt.ylim([min(plt.ylim()),max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images 
  path = fn
  img = image.load_img(path, target_size = (224,224))
  imgplot = plt.imshow (img)
  x= image.img_to_array(img)
  x = np.expand_dims (x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size =10)
  print (fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes [0][j]== 1. :
      print ('Kelas :  ', class_list[j+1])
      break
# Out:
#      <input type="file" id="files-ea4c9a84-6c8a-4933-8b09-f7754107fad2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea4c9a84-6c8a-4933-8b09-f7754107fad2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2002 (6).jpg to 2002 (6) (1).jpg
# 2002 (6).jpg
# Kelas :   Batik Parang
